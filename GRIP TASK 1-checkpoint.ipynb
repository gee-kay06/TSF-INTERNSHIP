# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from the remote link
url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(10)
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
# Plotting the distribution of scores
s_data.plot(x ='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
sdata = pd.DataFrame(s_data)

# Extracting 'Hours' and 'Scores' into x and y
x = sdata['Hours']
y = sdata['Scores']

# %%
plt.scatter(x, y)
z= np.polyfit(x,y,1)
p=np.poly1d(z)
plt.plot(x,p(x), 'g-')
plt.show()

# %%
print(np.poly1d(p))
# Out:
#
# 9.776 x + 2.484

# %%
print(np.poly1d(p(9.25)))
# Out:
#
# 92.91
